# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\tando\Downloads\Compressed\household_power_consumption\household_power_consumption.txt")

# %%
df.to_csv("household_power.csv")

# %%
df1=pd.read_csv(r"C:\Users\tando\Downloads\household_power.csv")

# %%
df1
# Out:
#          Unnamed: 0        Date      Time Global_active_power  \
# 0                 0  16/12/2006  17:24:00               4.216
# 1                 1  16/12/2006  17:25:00               5.360
# 2                 2  16/12/2006  17:26:00               5.374
# 3                 3  16/12/2006  17:27:00               5.388
# 4                 4  16/12/2006  17:28:00               3.666
# ...             ...         ...       ...                 ...
# 2075254     2075254  26/11/2010  20:58:00               0.946
# 2075255     2075255  26/11/2010  20:59:00               0.944
# 2075256     2075256  26/11/2010  21:00:00               0.938
# 2075257     2075257  26/11/2010  21:01:00               0.934
# 2075258     2075258  26/11/2010  21:02:00               0.932
#
#         Global_reactive_power  Voltage Global_intensity Sub_metering_1  \
# 0                       0.418  234.840           18.400          0.000
# 1                       0.436  233.630           23.000          0.000
# 2                       0.498  233.290           23.000          0.000
# 3                       0.502  233.740           23.000          0.000
# 4                       0.528  235.680           15.800          0.000
# ...                       ...      ...              ...            ...
# 2075254                   0.0   240.43              4.0            0.0
# 2075255                   0.0    240.0              4.0            0.0
# 2075256                   0.0   239.82              3.8            0.0
# 2075257                   0.0    239.7              3.8            0.0
# 2075258                   0.0   239.55              3.8            0.0
#
#         Sub_metering_2  Sub_metering_3
# 0                1.000            17.0
# 1                1.000            16.0
# 2                2.000            17.0
# 3                1.000            17.0
# 4                1.000            17.0
# ...                ...             ...
# 2075254            0.0             0.0
# 2075255            0.0             0.0
# 2075256            0.0             0.0
# 2075257            0.0             0.0
# 2075258            0.0             0.0
#
# [2075259 rows x 10 columns]

# %%
dfc=df1

# %%
dfc=dfc.drop(['Unnamed: 0'],axis=1)

# %%
dfc.isnull().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# dtype: int64

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
#  6   Sub_metering_1         object
#  7   Sub_metering_2         object
#  8   Sub_metering_3         float64
# dtypes: float64(1), object(8)
# memory usage: 142.5+ MB

# %%
dfc[dfc.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Global_active_power, Global_reactive_power, Voltage, Global_intensity, Sub_metering_1, Sub_metering_2, Sub_metering_3]
# Index: []

# %%
dfc=dfc.sample(50000)

# %%
dfc.shape
# Out:
# (50000, 9)

# %%
dfc.isnull().sum()
# Out:
# Date                       0
# Time                       0
# Global_active_power        0
# Global_reactive_power      0
# Voltage                    0
# Global_intensity           0
# Sub_metering_1             0
# Sub_metering_2             0
# Sub_metering_3           635
# dtype: int64

# %%
patch_index=dfc[dfc['Global_active_power']=="?"].index

# %%
# Dropping technique

# %%
dfc_drop=dfc

# %%
for i in patch_index:
    dfc_drop=dfc_drop.drop(i)

# %%
dfc_drop.shape
# Out:
# (49365, 9)

# %%
15000-14813
# Out:
# 187

# %%
dfc_drop['Global_active_power']=pd.to_numeric(dfc_drop['Global_active_power'])

# %%
dfc_drop['Global_active_power']=pd.to_numeric(dfc_drop['Global_active_power'])
dfc_drop['Global_reactive_power']=pd.to_numeric(dfc_drop['Global_reactive_power'])
dfc_drop['Voltage']=pd.to_numeric(dfc_drop['Voltage'])
dfc_drop['Global_intensity']=pd.to_numeric(dfc_drop['Global_intensity'])
dfc_drop['Sub_metering_1']=pd.to_numeric(dfc_drop['Sub_metering_1'])
dfc_drop['Sub_metering_2']=pd.to_numeric(dfc_drop['Sub_metering_2'])
dfc_drop['Sub_metering_3']=pd.to_numeric(dfc_drop['Sub_metering_3'])

# %%
dfc_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49365 entries, 161682 to 178045
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   49365 non-null  object
#  1   Time                   49365 non-null  object
#  2   Global_active_power    49365 non-null  float64
#  3   Global_reactive_power  49365 non-null  float64
#  4   Voltage                49365 non-null  float64
#  5   Global_intensity       49365 non-null  float64
#  6   Sub_metering_1         49365 non-null  float64
#  7   Sub_metering_2         49365 non-null  float64
#  8   Sub_metering_3         49365 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 3.8+ MB

# %%
fig= plt.figure()

# density plot using seaborn library
fig, axs = plt.subplots(2, 2, figsize=(15, 7))

dfc_drop['Sub_metering_3'].plot.density(color='red',ax=axs[0, 0],alpha=0.5,label='Size')
dfc['Sub_metering_3'].plot.density(color='green',ax=axs[0, 0],alpha=0.5,label='Size')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
fig= plt.figure()

# density plot using seaborn library
fig, axs = plt.subplots(2, 2, figsize=(15, 7))
dfc_drop['Sub_metering_3'].hist(bins=50,ax=axs[0, 0],density=True,figsize=(12,12),color='red')
dfc['Sub_metering_3'].hist(bins=50,ax=axs[0, 0],density=True,figsize=(12,12),color='green', alpha=0.4)
plt.show()

# %%
# Almost follows the same graph

# %%
df_copy_mean = dfc

# %%
dropped_dfc=dfc

# %%
for i in patch_index:
    dropped_dfc.drop(i)

# %%
dropped_dfc['Global_active_power']=pd.to_numeric(dfc_drop['Global_active_power'])
dropped_dfc['Global_reactive_power']=pd.to_numeric(dfc_drop['Global_reactive_power'])
dropped_dfc['Voltage']=pd.to_numeric(dfc_drop['Voltage'])
dropped_dfc['Global_intensity']=pd.to_numeric(dfc_drop['Global_intensity'])
dropped_dfc['Sub_metering_1']=pd.to_numeric(dfc_drop['Sub_metering_1'])
dropped_dfc['Sub_metering_2']=pd.to_numeric(dfc_drop['Sub_metering_2'])
dropped_dfc['Sub_metering_3']=pd.to_numeric(dfc_drop['Sub_metering_3'])

# %%
glob_act_mean=dropped_dfc['Global_active_power'].mean()

# %%
glob_act_mean
# Out:
# 1.098174334042351

# %%
glob_act_mean=dropped_dfc['Global_active_power'].mean()
glob_rct_mean=dropped_dfc['Global_reactive_power'].mean()
vol=dropped_dfc['Voltage'].mean()
glo_int=dropped_dfc['Global_intensity'].mean()
sub_1=dropped_dfc['Sub_metering_1'].mean()
sub_2=dropped_dfc['Sub_metering_2'].mean()
sub_3=dropped_dfc['Sub_metering_3'].mean()

# %%
for i in patch_index:
    df_copy_mean['Global_active_power'].loc[i]=glob_act_mean
    df_copy_mean['Global_reactive_power'].loc[i]=glob_rct_mean
    df_copy_mean['Voltage'].loc[i]=vol
    df_copy_mean['Global_intensity'].loc[i]=glo_int
    df_copy_mean['Sub_metering_1'].loc[i]=sub_1
    df_copy_mean['Sub_metering_2'].loc[i]=sub_2
    df_copy_mean['Sub_metering_3'].loc[i]=sub_3

# %%
print('Original Size Variance', df_copy_mean['Global_active_power'].var())
print('Original Size Variance', df_copy_mean['Global_reactive_power'].var())
print('Original Size Variance', df_copy_mean['Voltage'].var())
print('Original Size Variance', df_copy_mean['Global_intensity'].var())
print('Original Size Variance', df_copy_mean['Sub_metering_1'].var())
print('Original Size Variance', df_copy_mean['Sub_metering_2'].var())
print('Original Size Variance', df_copy_mean['Sub_metering_3'].var())
# Out:
# Original Size Variance 1.111306828850207
# Original Size Variance 0.012564891664693762
# Original Size Variance 10.499675872133949
# Original Size Variance 19.617089602283727
# Original Size Variance 37.15974602036857
# Original Size Variance 34.90932020848793
# Original Size Variance 70.46697311545282

# %%
# median imputation

# %%
glob_act_med=dropped_dfc['Global_active_power'].median()
glob_rct_med=dropped_dfc['Global_reactive_power'].median()
vo_med=dropped_dfc['Voltage'].median()
glo_int_med=dropped_dfc['Global_intensity'].median()
sub_1_med=dropped_dfc['Sub_metering_1'].median()
sub_2_med=dropped_dfc['Sub_metering_2'].median()
sub_3_med=dropped_dfc['Sub_metering_3'].median()

# %%
df_copy_median = dfc

# %%
for i in patch_index:
    df_copy_median['Global_active_power'].loc[i]=glob_act_med
    df_copy_median['Global_reactive_power'].loc[i]=glob_rct_med
    df_copy_median['Voltage'].loc[i]=vo_med
    df_copy_median['Global_intensity'].loc[i]=glo_int_med
    df_copy_median['Sub_metering_1'].loc[i]=sub_1_med
    df_copy_median['Sub_metering_2'].loc[i]=sub_2_med
    df_copy_median['Sub_metering_3'].loc[i]=sub_3_med

# %%
print('Original Size Variance', df_copy_median['Global_active_power'].var())
print('Original Size Variance', df_copy_median['Global_reactive_power'].var())
print('Original Size Variance', df_copy_median['Voltage'].var())
print('Original Size Variance', df_copy_median['Global_intensity'].var())
print('Original Size Variance', df_copy_median['Sub_metering_1'].var())
print('Original Size Variance', df_copy_median['Sub_metering_2'].var())
print('Original Size Variance', df_copy_median['Sub_metering_3'].var())
# Out:
# Original Size Variance 1.114008445909236
# Original Size Variance 0.012570786940140632
# Original Size Variance 10.499886246576612
# Original Size Variance 19.660316546731583
# Original Size Variance 37.17535688271753
# Original Size Variance 34.931800394422794
# Original Size Variance 70.84152083041168

# %%
# As seen mean imputation gives less variance so that is fine

# %%
# Checking outliers

# %%
dfc_new=df_copy_mean

# %%
dfc_newc=dfc_new

# %%
dfc_new.shape
# Out:
# (50000, 9)

# %%
num_features=[col for col in dfc_new.columns if dfc_new[col].dtype!='O']
num_df = dfc_new[num_features]
num_df.head()
# Out:
#          Global_active_power  Global_reactive_power  Voltage  \
# 161682                 3.578                  0.310   239.38
# 1185516                0.296                  0.082   244.93
# 1018904                0.264                  0.062   241.61
# 929331                 0.252                  0.118   241.32
# 1027511                0.326                  0.094   244.57
#
#          Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 161682               15.0             0.0             1.0            18.0
# 1185516               1.2             0.0             0.0             0.0
# 1018904               1.2             0.0             0.0             0.0
# 929331                1.2             0.0             0.0             1.0
# 1027511               1.4             0.0             0.0             0.0

# %%
plt.figure(figsize=(22,18))
for i,col in enumerate(num_df.columns):
    plt.subplot(4,9,i+1)
    sns.boxplot(num_df[col])

# %%
# Function to detect outliers
def outlier_thresholds(dataframe, variable):
    quartile1 = dataframe[variable].quantile(0.25)
    quartile3 = dataframe[variable].quantile(0.75)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

# %%
## function to remove outliers
def replace_with_thresholds(dataframe, numeric_columns):
    for variable in numeric_columns:
        low_limit, up_limit = outlier_thresholds(dataframe, variable)
        dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
        dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %%
replace_with_thresholds(num_df, num_df.columns)

# %%
plt.figure(figsize=(22,18))
for i,col in enumerate(num_df.columns):
    plt.subplot(4,9,i+1)
    sns.boxplot(num_df[col])

# %%
# As we can see from above boxplots outliers are removed properly

# %%
num_df.columns
# Out:
# Index(['Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
for i in num_df.columns:
    dfc_newc[i]=num_df[i]

# %%
num_features=[col for col in dfc_new.columns if dfc_newc[col].dtype!='O']
num_df = dfc_newc[num_features]
num_df.head()
# Out:
#          Global_active_power  Global_reactive_power  Voltage  \
# 161682                 3.360                  0.310   239.38
# 1185516                0.296                  0.082   244.93
# 1018904                0.264                  0.062   241.61
# 929331                 0.252                  0.118   241.32
# 1027511                0.326                  0.094   244.57
#
#          Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 161682               13.9             0.0             1.0            18.0
# 1185516               1.2             0.0             0.0             0.0
# 1018904               1.2             0.0             0.0             0.0
# 929331                1.2             0.0             0.0             1.0
# 1027511               1.4             0.0             0.0             0.0

# %%
plt.figure(figsize=(22,18))
for i,col in enumerate(num_df.columns):
    plt.subplot(4,9,i+1)
    sns.boxplot(num_df[col])

# %%
# Correlations among columns
plt.matshow(df_copy_mean.corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('without resampling', size=15)
plt.colorbar()
plt.show()

# %%
df_cleaned=dfc_newc

# %%
df_cleaned_copy=df_cleaned

# %%
# Target Variable
eq1 = (df_cleaned_copy['Global_active_power']*1000/60) 
eq2 = df_cleaned_copy['Sub_metering_1'] + df_cleaned_copy['Sub_metering_2'] + df_cleaned_copy['Sub_metering_3']
df_cleaned_copy['power_consumption'] = eq1 - eq2
df_cleaned_copy.head()
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 161682     8/4/2007  00:06:00                3.360                  0.310
# 1185516   19/3/2009  00:00:00                0.296                  0.082
# 1018904  23/11/2008  07:08:00                0.264                  0.062
# 929331    22/9/2008  02:15:00                0.252                  0.118
# 1027511  29/11/2008  06:35:00                0.326                  0.094
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 161682    239.38              13.9             0.0             1.0
# 1185516   244.93               1.2             0.0             0.0
# 1018904   241.61               1.2             0.0             0.0
# 929331    241.32               1.2             0.0             0.0
# 1027511   244.57               1.4             0.0             0.0
#
#          Sub_metering_3  power_consumption
# 161682             18.0          37.000000
# 1185516             0.0           4.933333
# 1018904             0.0           4.400000
# 929331              1.0           3.200000
# 1027511             0.0           5.433333

# %%
# Distribution of the target variables
sns.histplot(data=df_cleaned_copy, x='power_consumption', bins=15, kde=True)
plt.show()

# %%
dfc_newc
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 161682     8/4/2007  00:06:00                3.360                  0.310
# 1185516   19/3/2009  00:00:00                0.296                  0.082
# 1018904  23/11/2008  07:08:00                0.264                  0.062
# 929331    22/9/2008  02:15:00                0.252                  0.118
# 1027511  29/11/2008  06:35:00                0.326                  0.094
# ...             ...       ...                  ...                    ...
# 1399473   14/8/2009  13:57:00                0.402                  0.204
# 1333570   29/6/2009  19:34:00                0.286                  0.108
# 479027   14/11/2007  09:11:00                1.396                  0.086
# 1913778    6/8/2010  17:42:00                0.286                  0.166
# 178045    19/4/2007  08:49:00                1.302                  0.124
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 161682    239.38              13.9             0.0             1.0
# 1185516   244.93               1.2             0.0             0.0
# 1018904   241.61               1.2             0.0             0.0
# 929331    241.32               1.2             0.0             0.0
# 1027511   244.57               1.4             0.0             0.0
# ...          ...               ...             ...             ...
# 1399473   238.76               1.8             0.0             0.0
# 1333570   240.93               1.2             0.0             0.0
# 479027    237.83               5.8             0.0             0.0
# 1913778   239.88               1.4             0.0             0.0
# 178045    242.38               5.4             0.0             0.0
#
#          Sub_metering_3  power_consumption
# 161682             18.0          37.000000
# 1185516             0.0           4.933333
# 1018904             0.0           4.400000
# 929331              1.0           3.200000
# 1027511             0.0           5.433333
# ...                 ...                ...
# 1399473             0.0           6.700000
# 1333570             0.0           4.766667
# 479027             18.0           5.266667
# 1913778             1.0           3.766667
# 178045             18.0           3.700000
#
# [50000 rows x 10 columns]

# %%
# Defining Target variabe

# %%
X = df_cleaned_copy.drop(['Global_active_power'], axis=1)
y = df_cleaned_copy['Global_active_power']

# %%
# Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
df_cleaned_copy
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 161682     8/4/2007  00:06:00                3.360                  0.310
# 1185516   19/3/2009  00:00:00                0.296                  0.082
# 1018904  23/11/2008  07:08:00                0.264                  0.062
# 929331    22/9/2008  02:15:00                0.252                  0.118
# 1027511  29/11/2008  06:35:00                0.326                  0.094
# ...             ...       ...                  ...                    ...
# 1399473   14/8/2009  13:57:00                0.402                  0.204
# 1333570   29/6/2009  19:34:00                0.286                  0.108
# 479027   14/11/2007  09:11:00                1.396                  0.086
# 1913778    6/8/2010  17:42:00                0.286                  0.166
# 178045    19/4/2007  08:49:00                1.302                  0.124
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 161682    239.38              13.9             0.0             1.0
# 1185516   244.93               1.2             0.0             0.0
# 1018904   241.61               1.2             0.0             0.0
# 929331    241.32               1.2             0.0             0.0
# 1027511   244.57               1.4             0.0             0.0
# ...          ...               ...             ...             ...
# 1399473   238.76               1.8             0.0             0.0
# 1333570   240.93               1.2             0.0             0.0
# 479027    237.83               5.8             0.0             0.0
# 1913778   239.88               1.4             0.0             0.0
# 178045    242.38               5.4             0.0             0.0
#
#          Sub_metering_3  power_consumption
# 161682             18.0          37.000000
# 1185516             0.0           4.933333
# 1018904             0.0           4.400000
# 929331              1.0           3.200000
# 1027511             0.0           5.433333
# ...                 ...                ...
# 1399473             0.0           6.700000
# 1333570             0.0           4.766667
# 479027             18.0           5.266667
# 1913778             1.0           3.766667
# 178045             18.0           3.700000
#
# [50000 rows x 10 columns]

# %%
df_cleaned_copy['Day_scrapped']=pd.to_datetime(df_cleaned_copy['Date']).dt.day

# %%
df_cleaned_copy
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 161682     8/4/2007  00:06:00                3.360                  0.310
# 1185516   19/3/2009  00:00:00                0.296                  0.082
# 1018904  23/11/2008  07:08:00                0.264                  0.062
# 929331    22/9/2008  02:15:00                0.252                  0.118
# 1027511  29/11/2008  06:35:00                0.326                  0.094
# ...             ...       ...                  ...                    ...
# 1399473   14/8/2009  13:57:00                0.402                  0.204
# 1333570   29/6/2009  19:34:00                0.286                  0.108
# 479027   14/11/2007  09:11:00                1.396                  0.086
# 1913778    6/8/2010  17:42:00                0.286                  0.166
# 178045    19/4/2007  08:49:00                1.302                  0.124
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 161682    239.38              13.9             0.0             1.0
# 1185516   244.93               1.2             0.0             0.0
# 1018904   241.61               1.2             0.0             0.0
# 929331    241.32               1.2             0.0             0.0
# 1027511   244.57               1.4             0.0             0.0
# ...          ...               ...             ...             ...
# 1399473   238.76               1.8             0.0             0.0
# 1333570   240.93               1.2             0.0             0.0
# 479027    237.83               5.8             0.0             0.0
# 1913778   239.88               1.4             0.0             0.0
# 178045    242.38               5.4             0.0             0.0
#
#          Sub_metering_3  power_consumption  Day_scrapped
# 161682             18.0          37.000000             4
# 1185516             0.0           4.933333            19
# 1018904             0.0           4.400000            23
# 929331              1.0           3.200000            22
# 1027511             0.0           5.433333            29
# ...                 ...                ...           ...
# 1399473             0.0           6.700000            14
# 1333570             0.0           4.766667            29
# 479027             18.0           5.266667            14
# 1913778             1.0           3.766667             8
# 178045             18.0           3.700000            19
#
# [50000 rows x 11 columns]

# %%
df_cleaned_copy['Month_scrapped']=pd.to_datetime(df_cleaned_copy['Date']).dt.month

# %%
df_cleaned_copy['Year_scrapped']=pd.to_datetime(df_cleaned_copy['Date']).dt.year

# %%
df_cleaned_copy['Hour_of_day']=pd.to_datetime(df_cleaned_copy['Time']).dt.hour

# %%
df_cleaned_copy
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 161682     8/4/2007  00:06:00                3.360                  0.310
# 1185516   19/3/2009  00:00:00                0.296                  0.082
# 1018904  23/11/2008  07:08:00                0.264                  0.062
# 929331    22/9/2008  02:15:00                0.252                  0.118
# 1027511  29/11/2008  06:35:00                0.326                  0.094
# ...             ...       ...                  ...                    ...
# 1399473   14/8/2009  13:57:00                0.402                  0.204
# 1333570   29/6/2009  19:34:00                0.286                  0.108
# 479027   14/11/2007  09:11:00                1.396                  0.086
# 1913778    6/8/2010  17:42:00                0.286                  0.166
# 178045    19/4/2007  08:49:00                1.302                  0.124
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 161682    239.38              13.9             0.0             1.0
# 1185516   244.93               1.2             0.0             0.0
# 1018904   241.61               1.2             0.0             0.0
# 929331    241.32               1.2             0.0             0.0
# 1027511   244.57               1.4             0.0             0.0
# ...          ...               ...             ...             ...
# 1399473   238.76               1.8             0.0             0.0
# 1333570   240.93               1.2             0.0             0.0
# 479027    237.83               5.8             0.0             0.0
# 1913778   239.88               1.4             0.0             0.0
# 178045    242.38               5.4             0.0             0.0
#
#          Sub_metering_3  power_consumption  Day_scrapped  Month_scrapped  \
# 161682             18.0          37.000000             4               8
# 1185516             0.0           4.933333            19               3
# 1018904             0.0           4.400000            23              11
# 929331              1.0           3.200000            22               9
# 1027511             0.0           5.433333            29              11
# ...                 ...                ...           ...             ...
# 1399473             0.0           6.700000            14               8
# 1333570             0.0           4.766667            29               6
# 479027             18.0           5.266667            14              11
# 1913778             1.0           3.766667             8               6
# 178045             18.0           3.700000            19               4
#
#          Year_scrapped  Hour_of_day
# 161682            2007            0
# 1185516           2009            0
# 1018904           2008            7
# 929331            2008            2
# 1027511           2008            6
# ...                ...          ...
# 1399473           2009           13
# 1333570           2009           19
# 479027            2007            9
# 1913778           2010           17
# 178045            2007            8
#
# [50000 rows x 14 columns]

# %%
df_cleaned_copy=df_cleaned_copy.drop(['Date','Time'],axis=1)

# %%
df_cleaned_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 161682 to 178045
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Global_active_power    50000 non-null  float64
#  1   Global_reactive_power  50000 non-null  float64
#  2   Voltage                50000 non-null  float64
#  3   Global_intensity       50000 non-null  float64
#  4   Sub_metering_1         50000 non-null  float64
#  5   Sub_metering_2         50000 non-null  float64
#  6   Sub_metering_3         50000 non-null  float64
#  7   power_consumption      50000 non-null  float64
#  8   Day_scrapped           50000 non-null  int64
#  9   Month_scrapped         50000 non-null  int64
#  10  Year_scrapped          50000 non-null  int64
#  11  Hour_of_day            50000 non-null  int64
# dtypes: float64(8), int64(4)
# memory usage: 6.0 MB

# %%
# Now dfc_cleaned_copy is ready for EDA analysis

# %%
# space for EDA Analysis

# %%
# Defining Target variabe

X = df_cleaned_copy.drop(['Global_active_power'], axis=1)
y = df_cleaned_copy['Global_active_power']

# %%
X
# Out:
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 161682                   0.310   239.38              13.9             0.0
# 1185516                  0.082   244.93               1.2             0.0
# 1018904                  0.062   241.61               1.2             0.0
# 929331                   0.118   241.32               1.2             0.0
# 1027511                  0.094   244.57               1.4             0.0
# ...                        ...      ...               ...             ...
# 1399473                  0.204   238.76               1.8             0.0
# 1333570                  0.108   240.93               1.2             0.0
# 479027                   0.086   237.83               5.8             0.0
# 1913778                  0.166   239.88               1.4             0.0
# 178045                   0.124   242.38               5.4             0.0
#
#          Sub_metering_2  Sub_metering_3  power_consumption  Day_scrapped  \
# 161682              1.0            18.0          37.000000             4
# 1185516             0.0             0.0           4.933333            19
# 1018904             0.0             0.0           4.400000            23
# 929331              0.0             1.0           3.200000            22
# 1027511             0.0             0.0           5.433333            29
# ...                 ...             ...                ...           ...
# 1399473             0.0             0.0           6.700000            14
# 1333570             0.0             0.0           4.766667            29
# 479027              0.0            18.0           5.266667            14
# 1913778             0.0             1.0           3.766667             8
# 178045              0.0            18.0           3.700000            19
#
#          Month_scrapped  Year_scrapped  Hour_of_day
# 161682                8           2007            0
# 1185516               3           2009            0
# 1018904              11           2008            7
# 929331                9           2008            2
# 1027511              11           2008            6
# ...                 ...            ...          ...
# 1399473               8           2009           13
# 1333570               6           2009           19
# 479027               11           2007            9
# 1913778               6           2010           17
# 178045                4           2007            8
#
# [50000 rows x 11 columns]

# %%
# Standarization or feature scaling the datasets

from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train_scaled=scaler.fit_transform(X_train)

# %%
X_test_scaled=scaler.transform(X_test)

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\tando\anaconda3\lib\site-packages (4.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
preprocess_model = [X_train,y_train,X_test,y_test]

# %%
import pickle

pickle.dump(preprocess_model, open('preprocess_model.pkl','wb'))

# %%
df_mongo=pd.DataFrame(X)
df_mongo['Global_active_power']=pd.DataFrame(y)

# %%
df_mongo
# Out:
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 161682                   0.310   239.38              13.9             0.0
# 1185516                  0.082   244.93               1.2             0.0
# 1018904                  0.062   241.61               1.2             0.0
# 929331                   0.118   241.32               1.2             0.0
# 1027511                  0.094   244.57               1.4             0.0
# ...                        ...      ...               ...             ...
# 1399473                  0.204   238.76               1.8             0.0
# 1333570                  0.108   240.93               1.2             0.0
# 479027                   0.086   237.83               5.8             0.0
# 1913778                  0.166   239.88               1.4             0.0
# 178045                   0.124   242.38               5.4             0.0
#
#          Sub_metering_2  Sub_metering_3  power_consumption  Day_scrapped  \
# 161682              1.0            18.0          37.000000             4
# 1185516             0.0             0.0           4.933333            19
# 1018904             0.0             0.0           4.400000            23
# 929331              0.0             1.0           3.200000            22
# 1027511             0.0             0.0           5.433333            29
# ...                 ...             ...                ...           ...
# 1399473             0.0             0.0           6.700000            14
# 1333570             0.0             0.0           4.766667            29
# 479027              0.0            18.0           5.266667            14
# 1913778             0.0             1.0           3.766667             8
# 178045              0.0            18.0           3.700000            19
#
#          Month_scrapped  Year_scrapped  Hour_of_day  Global_active_power
# 161682                8           2007            0                3.360
# 1185516               3           2009            0                0.296
# 1018904              11           2008            7                0.264
# 929331                9           2008            2                0.252
# 1027511              11           2008            6                0.326
# ...                 ...            ...          ...                  ...
# 1399473               8           2009           13                0.402
# 1333570               6           2009           19                0.286
# 479027               11           2007            9                1.396
# 1913778               6           2010           17                0.286
# 178045                4           2007            8                1.302
#
# [50000 rows x 12 columns]

# %%
p=[]
for i,row in df_mongo.iterrows():
    p.append(dict(row))

# %%
p
# Out:
# [{'Global_reactive_power': 0.31,
#   'Voltage': 239.38,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 37.00000000000001,
#   'Day_scrapped': 4.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.082,
#   'Voltage': 244.93,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.933333333333334,
#   'Day_scrapped': 19.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 0.296},
#  {'Global_reactive_power': 0.062,
#   'Voltage': 241.61,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.4,
#   'Day_scrapped': 23.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 7.0,
#   'Global_active_power': 0.264},
#  {'Global_reactive_power': 0.118,
#   'Voltage': 241.32,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.2,
#   'Day_scrapped': 22.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.252},
#  {'Global_reactive_power': 0.094,
#   'Voltage': 244.57,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.433333333333334,
#   'Day_scrapped': 29.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 0.326},
#  {'Global_reactive_power': 0.15,
#   'Voltage': 237.53,
#   'Global_intensity': 13.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 34.4,
#   'Day_scrapped': 13.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 21.0,
#   'Global_active_power': 3.084},
#  {'Global_reactive_power': 0.236,
#   'Voltage': 242.82,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.033333333333333,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 0.302},
#  {'Global_reactive_power': 0.254,
#   'Voltage': 242.91,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.5999999999999996,
#   'Day_scrapped': 29.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 1.0,
#   'Global_active_power': 0.336},
#  {'Global_reactive_power': 0.186,
#   'Voltage': 244.02,
#   'Global_intensity': 3.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 11.0,
#   'power_consumption': 3.466666666666667,
#   'Day_scrapped': 3.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 0.868},
#  {'Global_reactive_power': 0.338,
#   'Voltage': 239.54,
#   'Global_intensity': 2.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.666666666666667,
#   'Day_scrapped': 6.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 10.0,
#   'Global_active_power': 0.4},
#  {'Global_reactive_power': 0.09,
#   'Voltage': 243.4,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 2.6333333333333333,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 20.0,
#   'Global_active_power': 0.218},
#  {'Global_reactive_power': 0.062,
#   'Voltage': 239.37,
#   'Global_intensity': 5.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 3.8000000000000007,
#   'Day_scrapped': 30.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 1.308},
#  {'Global_reactive_power': 0.084,
#   'Voltage': 245.14,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.7666666666666666,
#   'Day_scrapped': 4.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 0.346},
#  {'Global_reactive_power': 0.254,
#   'Voltage': 244.86,
#   'Global_intensity': 2.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 6.833333333333333,
#   'Day_scrapped': 1.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 5.0,
#   'Global_active_power': 0.47},
#  {'Global_reactive_power': 0.11,
#   'Voltage': 242.48,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.766666666666667,
#   'Day_scrapped': 19.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 0.346},
#  {'Global_reactive_power': 0.078,
#   'Voltage': 240.34,
#   'Global_intensity': 3.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 7.0,
#   'power_consumption': 3.966666666666667,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 15.0,
#   'Global_active_power': 0.718},
#  {'Global_reactive_power': 0.122,
#   'Voltage': 234.79,
#   'Global_intensity': 6.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 6.166666666666668,
#   'Day_scrapped': 6.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 1.45},
#  {'Global_reactive_power': 0.092,
#   'Voltage': 237.77,
#   'Global_intensity': 11.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 26.46666666666667,
#   'Day_scrapped': 4.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 21.0,
#   'Global_active_power': 2.668},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 245.54,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.6666666666666665,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.22},
#  {'Global_reactive_power': 0.212,
#   'Voltage': 242.48,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.2,
#   'Day_scrapped': 15.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 0.312},
#  {'Global_reactive_power': 0.24,
#   'Voltage': 242.78,
#   'Global_intensity': 1.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.966666666666667,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.358},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 236.22,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 38.00000000000001,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.15,
#   'Voltage': 244.0,
#   'Global_intensity': 5.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 18.466666666666665,
#   'Day_scrapped': 18.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 22.0,
#   'Global_active_power': 1.228},
#  {'Global_reactive_power': 0.202,
#   'Voltage': 240.12,
#   'Global_intensity': 10.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 22.799999999999997,
#   'Day_scrapped': 1.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 7.0,
#   'Global_active_power': 2.448},
#  {'Global_reactive_power': 0.088,
#   'Voltage': 245.09,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.833333333333333,
#   'Day_scrapped': 19.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 0.35},
#  {'Global_reactive_power': 0.334,
#   'Voltage': 235.59,
#   'Global_intensity': 4.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 14.833333333333334,
#   'Day_scrapped': 16.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 20.0,
#   'Global_active_power': 0.89},
#  {'Global_reactive_power': 0.098,
#   'Voltage': 234.53,
#   'Global_intensity': 11.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 25.1,
#   'Day_scrapped': 5.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 9.0,
#   'Global_active_power': 2.586},
#  {'Global_reactive_power': 0.17,
#   'Voltage': 243.01,
#   'Global_intensity': 3.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 11.0,
#   'power_consumption': 1.9000000000000004,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 0.774},
#  {'Global_reactive_power': 0.092,
#   'Voltage': 238.7,
#   'Global_intensity': 2.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 9.2,
#   'Day_scrapped': 2.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 22.0,
#   'Global_active_power': 0.552},
#  {'Global_reactive_power': 0.194,
#   'Voltage': 239.77,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 7.2,
#   'Day_scrapped': 4.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 1.0,
#   'Global_active_power': 0.432},
#  {'Global_reactive_power': 0.074,
#   'Voltage': 237.93,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 2.6333333333333333,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 0.218},
#  {'Global_reactive_power': 0.2,
#   'Voltage': 240.23,
#   'Global_intensity': 6.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 8.266666666666666,
#   'Day_scrapped': 2.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 12.0,
#   'Global_active_power': 1.636},
#  {'Global_reactive_power': 0.082,
#   'Voltage': 241.57,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.3666666666666663,
#   'Day_scrapped': 14.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 15.0,
#   'Global_active_power': 0.262},
#  {'Global_reactive_power': 0.064,
#   'Voltage': 240.08,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 8.4,
#   'Day_scrapped': 18.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 11.0,
#   'Global_active_power': 0.504},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 241.77,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.6333333333333333,
#   'Day_scrapped': 4.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 0.218},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 243.34,
#   'Global_intensity': 8.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 14.866666666666667,
#   'Day_scrapped': 6.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 2.032},
#  {'Global_reactive_power': 0.12,
#   'Voltage': 238.82,
#   'Global_intensity': 6.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 9.0,
#   'Day_scrapped': 20.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 1.62},
#  {'Global_reactive_power': 0.398,
#   'Voltage': 238.09,
#   'Global_intensity': 4.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 12.0,
#   'power_consumption': 3.6999999999999993,
#   'Day_scrapped': 30.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 1.002},
#  {'Global_reactive_power': 0.374,
#   'Voltage': 244.48,
#   'Global_intensity': 2.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.766666666666667,
#   'Day_scrapped': 2.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 0.466},
#  {'Global_reactive_power': 0.12,
#   'Voltage': 241.31,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 1.2666666666666666,
#   'Day_scrapped': 29.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.196},
#  {'Global_reactive_power': 0.078,
#   'Voltage': 239.79,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.0,
#   'Day_scrapped': 10.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 0.3},
#  {'Global_reactive_power': 0.21,
#   'Voltage': 242.93,
#   'Global_intensity': 1.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.6,
#   'Day_scrapped': 30.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 4.0,
#   'Global_active_power': 0.396},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 242.48,
#   'Global_intensity': 5.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 4.133333333333333,
#   'Day_scrapped': 10.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 9.0,
#   'Global_active_power': 1.328},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 239.78,
#   'Global_intensity': 5.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 4.5,
#   'Day_scrapped': 4.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 9.0,
#   'Global_active_power': 1.29},
#  {'Global_reactive_power': 0.226,
#   'Voltage': 238.08,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.3,
#   'Day_scrapped': 24.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.318},
#  {'Global_reactive_power': 0.112,
#   'Voltage': 241.13,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.5666666666666664,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 0.274},
#  {'Global_reactive_power': 0.098,
#   'Voltage': 240.62,
#   'Global_intensity': 10.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 23.9,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 2.514},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 242.85,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.033333333333333,
#   'Day_scrapped': 10.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 0.242},
#  {'Global_reactive_power': 0.33,
#   'Voltage': 242.46,
#   'Global_intensity': 6.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 6.433333333333334,
#   'Day_scrapped': 4.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 14.0,
#   'Global_active_power': 1.526},
#  {'Global_reactive_power': 0.148,
#   'Voltage': 237.92,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 0.9666666666666668,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 0.178},
#  {'Global_reactive_power': 0.114,
#   'Voltage': 243.62,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 5.066666666666666,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 0.364},
#  {'Global_reactive_power': 0.218,
#   'Voltage': 238.16,
#   'Global_intensity': 7.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 27.733333333333334,
#   'Day_scrapped': 14.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 1.784},
#  {'Global_reactive_power': 0.17,
#   'Voltage': 233.21,
#   'Global_intensity': 2.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 7.8,
#   'Day_scrapped': 28.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 0.468},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 235.47,
#   'Global_intensity': 4.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 1.3999999999999986,
#   'Day_scrapped': 8.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 1.164},
#  {'Global_reactive_power': 0.236,
#   'Voltage': 241.66,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.666666666666667,
#   'Day_scrapped': 16.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 0.34},
#  {'Global_reactive_power': 0.40800000000000003,
#   'Voltage': 236.64,
#   'Global_intensity': 5.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 12.0,
#   'power_consumption': 4.300000000000001,
#   'Day_scrapped': 29.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 11.0,
#   'Global_active_power': 1.098},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 242.35,
#   'Global_intensity': 12.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 30.53333333333333,
#   'Day_scrapped': 31.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 2.912},
#  {'Global_reactive_power': 0.216,
#   'Voltage': 238.95,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.1,
#   'Day_scrapped': 6.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.306},
#  {'Global_reactive_power': 0.062,
#   'Voltage': 239.31,
#   'Global_intensity': 6.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 6.699999999999999,
#   'Day_scrapped': 3.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 1.542},
#  {'Global_reactive_power': 0.266,
#   'Voltage': 240.49,
#   'Global_intensity': 6.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 26.166666666666668,
#   'Day_scrapped': 29.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 1.63},
#  {'Global_reactive_power': 0.254,
#   'Voltage': 241.53,
#   'Global_intensity': 3.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 6.0,
#   'power_consumption': 5.1,
#   'Day_scrapped': 11.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 0.666},
#  {'Global_reactive_power': 0.074,
#   'Voltage': 241.77,
#   'Global_intensity': 5.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 2.166666666666668,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 22.0,
#   'Global_active_power': 1.39},
#  {'Global_reactive_power': 0.094,
#   'Voltage': 240.89,
#   'Global_intensity': 5.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 3.166666666666668,
#   'Day_scrapped': 21.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 1.27},
#  {'Global_reactive_power': 0.40800000000000003,
#   'Voltage': 242.94,
#   'Global_intensity': 5.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 19.933333333333334,
#   'Day_scrapped': 12.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 1.196},
#  {'Global_reactive_power': 0.094,
#   'Voltage': 245.32,
#   'Global_intensity': 5.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 4.199999999999999,
#   'Day_scrapped': 3.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 10.0,
#   'Global_active_power': 1.452},
#  {'Global_reactive_power': 0.112,
#   'Voltage': 241.77,
#   'Global_intensity': 6.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 25.133333333333333,
#   'Day_scrapped': 11.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 1.508},
#  {'Global_reactive_power': 0.40800000000000003,
#   'Voltage': 236.9,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 36.00000000000001,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 237.19,
#   'Global_intensity': 6.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 9.899999999999999,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 21.0,
#   'Global_active_power': 1.614},
#  {'Global_reactive_power': 0.064,
#   'Voltage': 243.98,
#   'Global_intensity': 2.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 8.766666666666667,
#   'Day_scrapped': 31.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 0.526},
#  {'Global_reactive_power': 0.234,
#   'Voltage': 242.34,
#   'Global_intensity': 3.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 12.833333333333334,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 0.83},
#  {'Global_reactive_power': 0.38,
#   'Voltage': 243.03,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.5,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 35.50000000000001,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 15.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.114,
#   'Voltage': 241.58,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.333333333333333,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.26},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 241.99,
#   'Global_intensity': 5.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 4.699999999999999,
#   'Day_scrapped': 5.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 10.0,
#   'Global_active_power': 1.422},
#  {'Global_reactive_power': 0.126,
#   'Voltage': 237.69,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.4,
#   'Day_scrapped': 8.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 7.0,
#   'Global_active_power': 0.204},
#  {'Global_reactive_power': 0.092,
#   'Voltage': 235.91,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.5999999999999996,
#   'Day_scrapped': 31.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 0.276},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 238.84,
#   'Global_intensity': 11.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 30.5,
#   'Day_scrapped': 31.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 2.85},
#  {'Global_reactive_power': 0.11,
#   'Voltage': 235.44,
#   'Global_intensity': 12.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 33.36666666666667,
#   'Day_scrapped': 2.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 3.022},
#  {'Global_reactive_power': 0.198,
#   'Voltage': 244.92,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 6.133333333333334,
#   'Day_scrapped': 15.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 14.0,
#   'Global_active_power': 0.368},
#  {'Global_reactive_power': 0.074,
#   'Voltage': 240.23,
#   'Global_intensity': 7.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 11.633333333333333,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 1.778},
#  {'Global_reactive_power': 0.122,
#   'Voltage': 240.58,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 1.6333333333333333,
#   'Day_scrapped': 22.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 0.158},
#  {'Global_reactive_power': 0.212,
#   'Voltage': 245.09,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.033333333333333,
#   'Day_scrapped': 21.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2006.0,
#   'Hour_of_day': 5.0,
#   'Global_active_power': 0.362},
#  {'Global_reactive_power': 0.062,
#   'Voltage': 241.46,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.566666666666667,
#   'Day_scrapped': 12.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 1.0,
#   'Global_active_power': 0.214},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 244.71,
#   'Global_intensity': 4.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 16.233333333333334,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 22.0,
#   'Global_active_power': 1.094},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 240.95,
#   'Global_intensity': 2.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 9.566666666666666,
#   'Day_scrapped': 13.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 20.0,
#   'Global_active_power': 0.634},
#  {'Global_reactive_power': 0.112,
#   'Voltage': 239.23,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.066666666666667,
#   'Day_scrapped': 19.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 0.184},
#  {'Global_reactive_power': 0.23,
#   'Voltage': 243.55,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.8,
#   'Day_scrapped': 6.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.348},
#  {'Global_reactive_power': 0.168,
#   'Voltage': 233.74,
#   'Global_intensity': 10.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.5,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 40.03333333333333,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 10.0,
#   'Global_active_power': 2.552},
#  {'Global_reactive_power': 0.292,
#   'Voltage': 235.66,
#   'Global_intensity': 2.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.5,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 7.533333333333333,
#   'Day_scrapped': 6.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 12.0,
#   'Global_active_power': 0.602},
#  {'Global_reactive_power': 0.27,
#   'Voltage': 237.28,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 38.00000000000001,
#   'Day_scrapped': 30.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 243.76,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.166666666666667,
#   'Day_scrapped': 5.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.25},
#  {'Global_reactive_power': 0.11,
#   'Voltage': 240.43,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.733333333333333,
#   'Day_scrapped': 24.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 10.0,
#   'Global_active_power': 0.344},
#  {'Global_reactive_power': 0.194,
#   'Voltage': 236.65,
#   'Global_intensity': 6.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 6.933333333333334,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 1.496},
#  {'Global_reactive_power': 0.104,
#   'Voltage': 242.22,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.333333333333333,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 0.32},
#  {'Global_reactive_power': 0.236,
#   'Voltage': 241.98,
#   'Global_intensity': 2.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 9.133333333333333,
#   'Day_scrapped': 16.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 0.548},
#  {'Global_reactive_power': 0.37,
#   'Voltage': 241.56,
#   'Global_intensity': 6.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 4.399999999999999,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 1.464},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 234.41,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.8,
#   'Day_scrapped': 5.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 1.0,
#   'Global_active_power': 0.348},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 240.28,
#   'Global_intensity': 0.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 1.4333333333333331,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 20.0,
#   'Global_active_power': 0.146},
#  {'Global_reactive_power': 0.40800000000000003,
#   'Voltage': 240.97,
#   'Global_intensity': 4.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 12.0,
#   'power_consumption': 5.899999999999999,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 1.074},
#  {'Global_reactive_power': 0.18,
#   'Voltage': 242.9,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.566666666666666,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.334},
#  {'Global_reactive_power': 0.112,
#   'Voltage': 242.69,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 2.033333333333333,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 0.242},
#  {'Global_reactive_power': 0.116,
#   'Voltage': 243.71,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.6,
#   'Day_scrapped': 4.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.336},
#  {'Global_reactive_power': 0.058,
#   'Voltage': 238.34,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 7.066666666666666,
#   'Day_scrapped': 11.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 0.424},
#  {'Global_reactive_power': 0.244,
#   'Voltage': 243.74,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 55.00000000000001,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 15.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.098,
#   'Voltage': 244.22,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.3666666666666663,
#   'Day_scrapped': 22.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 15.0,
#   'Global_active_power': 0.322},
#  {'Global_reactive_power': 0.234,
#   'Voltage': 243.06,
#   'Global_intensity': 1.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 5.1,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 4.0,
#   'Global_active_power': 0.366},
#  {'Global_reactive_power': 0.092,
#   'Voltage': 238.58,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 2.8666666666666663,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 11.0,
#   'Global_active_power': 0.292},
#  {'Global_reactive_power': 0.088,
#   'Voltage': 239.09,
#   'Global_intensity': 6.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 7.666666666666668,
#   'Day_scrapped': 15.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 1.6},
#  {'Global_reactive_power': 0.08,
#   'Voltage': 233.93,
#   'Global_intensity': 5.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 4.866666666666667,
#   'Day_scrapped': 8.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 1.312},
#  {'Global_reactive_power': 0.238,
#   'Voltage': 240.8,
#   'Global_intensity': 3.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 12.0,
#   'power_consumption': 1.9666666666666668,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 21.0,
#   'Global_active_power': 0.898},
#  {'Global_reactive_power': 0.326,
#   'Voltage': 238.43,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.5,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 0.39},
#  {'Global_reactive_power': 0.166,
#   'Voltage': 246.26,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.933333333333334,
#   'Day_scrapped': 2.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 0.356},
#  {'Global_reactive_power': 0.062,
#   'Voltage': 240.35,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.2666666666666666,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 5.0,
#   'Global_active_power': 0.196},
#  {'Global_reactive_power': 0.40800000000000003,
#   'Voltage': 240.29,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 54.00000000000001,
#   'Day_scrapped': 10.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 22.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.26,
#   'Voltage': 242.29,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.2666666666666666,
#   'Day_scrapped': 8.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 0.316},
#  {'Global_reactive_power': 0.062,
#   'Voltage': 244.43,
#   'Global_intensity': 3.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 11.9,
#   'Day_scrapped': 16.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 22.0,
#   'Global_active_power': 0.714},
#  {'Global_reactive_power': 0.11,
#   'Voltage': 245.31,
#   'Global_intensity': 6.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 6.766666666666666,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 9.0,
#   'Global_active_power': 1.546},
#  {'Global_reactive_power': 0.152,
#   'Voltage': 241.19,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.066666666666667,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 11.0,
#   'Global_active_power': 0.184},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 238.64,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 7.8,
#   'Day_scrapped': 19.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 14.0,
#   'Global_active_power': 0.468},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 242.75,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 3.833333333333333,
#   'Day_scrapped': 28.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.29},
#  {'Global_reactive_power': 0.1,
#   'Voltage': 233.59,
#   'Global_intensity': 7.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 16.0,
#   'power_consumption': 13.466666666666665,
#   'Day_scrapped': 5.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 14.0,
#   'Global_active_power': 1.768},
#  {'Global_reactive_power': 0.196,
#   'Voltage': 239.57,
#   'Global_intensity': 5.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 5.199999999999999,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 1.392},
#  {'Global_reactive_power': 0.106,
#   'Voltage': 246.92,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 6.033333333333333,
#   'Day_scrapped': 1.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 0.362},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 242.5,
#   'Global_intensity': 8.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 30.466666666666665,
#   'Day_scrapped': 30.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2006.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 1.828},
#  {'Global_reactive_power': 0.094,
#   'Voltage': 233.85,
#   'Global_intensity': 4.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 16.866666666666667,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 1.012},
#  {'Global_reactive_power': 0.128,
#   'Voltage': 240.06,
#   'Global_intensity': 4.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 19.5,
#   'Day_scrapped': 18.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 20.0,
#   'Global_active_power': 1.17},
#  {'Global_reactive_power': 0.234,
#   'Voltage': 236.41,
#   'Global_intensity': 8.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 16.9,
#   'Day_scrapped': 1.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 2.034},
#  {'Global_reactive_power': 0.17,
#   'Voltage': 240.29,
#   'Global_intensity': 6.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 5.800000000000001,
#   'Day_scrapped': 15.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 1.548},
#  {'Global_reactive_power': 0.072,
#   'Voltage': 233.15999999999997,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.066666666666666,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 14.0,
#   'Global_active_power': 0.304},
#  {'Global_reactive_power': 0.272,
#   'Voltage': 241.5,
#   'Global_intensity': 4.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 10.0,
#   'power_consumption': 7.366666666666667,
#   'Day_scrapped': 28.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 7.0,
#   'Global_active_power': 1.102},
#  {'Global_reactive_power': 0.07,
#   'Voltage': 244.17,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.066666666666666,
#   'Day_scrapped': 20.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.304},
#  {'Global_reactive_power': 0.064,
#   'Voltage': 244.68,
#   'Global_intensity': 1.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.3666666666666663,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 0.382},
#  {'Global_reactive_power': 0.104,
#   'Voltage': 244.27,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.733333333333333,
#   'Day_scrapped': 18.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 0.344},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 240.95,
#   'Global_intensity': 2.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 9.566666666666666,
#   'Day_scrapped': 20.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 11.0,
#   'Global_active_power': 0.634},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 240.95,
#   'Global_intensity': 2.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 9.566666666666666,
#   'Day_scrapped': 18.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.634},
#  {'Global_reactive_power': 0.40800000000000003,
#   'Voltage': 240.76,
#   'Global_intensity': 6.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 12.0,
#   'power_consumption': 9.533333333333335,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 16.0,
#   'Global_active_power': 1.352},
#  {'Global_reactive_power': 0.07,
#   'Voltage': 241.61,
#   'Global_intensity': 6.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 6.033333333333335,
#   'Day_scrapped': 12.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 10.0,
#   'Global_active_power': 1.442},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 240.81,
#   'Global_intensity': 0.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 2.2666666666666666,
#   'Day_scrapped': 8.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 21.0,
#   'Global_active_power': 0.136},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 242.14,
#   'Global_intensity': 0.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 1.7333333333333334,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 0.104},
#  {'Global_reactive_power': 0.12,
#   'Voltage': 240.66,
#   'Global_intensity': 9.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 36.5,
#   'Day_scrapped': 23.0,
#   'Month_scrapped': 1.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 2.19},
#  {'Global_reactive_power': 0.166,
#   'Voltage': 239.38,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.5,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 53.50000000000001,
#   'Day_scrapped': 25.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2006.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.056,
#   'Voltage': 234.72,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.5,
#   'Day_scrapped': 5.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 1.0,
#   'Global_active_power': 0.33},
#  {'Global_reactive_power': 0.186,
#   'Voltage': 236.54,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.5,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 52.50000000000001,
#   'Day_scrapped': 19.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 3.3600000000000003},
#  {'Global_reactive_power': 0.148,
#   'Voltage': 239.84,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 1.9,
#   'Day_scrapped': 8.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 0.174},
#  {'Global_reactive_power': 0.048,
#   'Voltage': 239.22,
#   'Global_intensity': 3.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 13.833333333333334,
#   'Day_scrapped': 11.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 12.0,
#   'Global_active_power': 0.83},
#  {'Global_reactive_power': 0.06,
#   'Voltage': 237.71,
#   'Global_intensity': 10.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.5,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 37.3,
#   'Day_scrapped': 16.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 12.0,
#   'Global_active_power': 2.448},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 239.55,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 4.2,
#   'Day_scrapped': 19.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 8.0,
# ...
#   'Voltage': 242.25,
#   'Global_intensity': 2.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 8.7,
#   'Day_scrapped': 5.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 0.522},
#  {'Global_reactive_power': 0.13,
#   'Voltage': 241.21,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 6.466666666666667,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 0.448},
#  {'Global_reactive_power': 0.092,
#   'Voltage': 241.68,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 2.933333333333333,
#   'Day_scrapped': 8.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 22.0,
#   'Global_active_power': 0.236},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 241.73,
#   'Global_intensity': 0.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 2.0,
#   'Day_scrapped': 21.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 12.0,
#   'Global_active_power': 0.12},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 242.11,
#   'Global_intensity': 1.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 1.9333333333333331,
#   'Day_scrapped': 14.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 6.0,
#   'Global_active_power': 0.176},
#  {'Global_reactive_power': 0.216,
#   'Voltage': 240.41,
#   'Global_intensity': 2.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 9.066666666666666,
#   'Day_scrapped': 5.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 4.0,
#   'Global_active_power': 0.604},
#  {'Global_reactive_power': 0.234,
#   'Voltage': 240.32,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 7.533333333333333,
#   'Day_scrapped': 22.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 11.0,
#   'Global_active_power': 0.452},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 240.95,
#   'Global_intensity': 2.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 9.566666666666666,
#   'Day_scrapped': 6.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 0.634},
#  {'Global_reactive_power': 0.2,
#   'Voltage': 241.81,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 6.2,
#   'Day_scrapped': 21.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 9.0,
#   'Global_active_power': 0.432},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 243.3,
#   'Global_intensity': 0.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 1.4,
#   'Day_scrapped': 16.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.084},
#  {'Global_reactive_power': 0.066,
#   'Voltage': 240.56,
#   'Global_intensity': 7.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 11.533333333333335,
#   'Day_scrapped': 13.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 11.0,
#   'Global_active_power': 1.772},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 240.95,
#   'Global_intensity': 2.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 9.566666666666666,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 0.634},
#  {'Global_reactive_power': 0.046,
#   'Voltage': 239.83,
#   'Global_intensity': 7.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.5,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 8.066666666666666,
#   'Day_scrapped': 14.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 1.714},
#  {'Global_reactive_power': 0.168,
#   'Voltage': 240.78,
#   'Global_intensity': 1.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 5.1,
#   'Day_scrapped': 16.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.426},
#  {'Global_reactive_power': 0.05,
#   'Voltage': 238.73,
#   'Global_intensity': 5.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 3.133333333333333,
#   'Day_scrapped': 3.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 9.0,
#   'Global_active_power': 1.268},
#  {'Global_reactive_power': 0.182,
#   'Voltage': 239.7,
#   'Global_intensity': 6.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 4.733333333333334,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 1.0,
#   'Global_active_power': 1.484},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 242.12,
#   'Global_intensity': 9.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 22.266666666666666,
#   'Day_scrapped': 11.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 2.416},
#  {'Global_reactive_power': 0.172,
#   'Voltage': 241.45,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.666666666666667,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.28},
#  {'Global_reactive_power': 0.346,
#   'Voltage': 241.83,
#   'Global_intensity': 2.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 7.133333333333333,
#   'Day_scrapped': 22.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 0.0,
#   'Global_active_power': 0.488},
#  {'Global_reactive_power': 0.106,
#   'Voltage': 236.78,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.8,
#   'Day_scrapped': 21.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 21.0,
#   'Global_active_power': 0.348},
#  {'Global_reactive_power': 0.40800000000000003,
#   'Voltage': 239.82,
#   'Global_intensity': 9.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 18.666666666666664,
#   'Day_scrapped': 1.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 2.2},
#  {'Global_reactive_power': 0.242,
#   'Voltage': 236.14,
#   'Global_intensity': 13.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 51.93333333333333,
#   'Day_scrapped': 3.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 12.0,
#   'Global_active_power': 3.116},
#  {'Global_reactive_power': 0.09,
#   'Voltage': 240.82,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.8,
#   'Day_scrapped': 14.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 0.288},
#  {'Global_reactive_power': 0.278,
#   'Voltage': 243.26,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.333333333333333,
#   'Day_scrapped': 20.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 20.0,
#   'Global_active_power': 0.32},
#  {'Global_reactive_power': 0.078,
#   'Voltage': 244.09,
#   'Global_intensity': 6.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 4.0,
#   'Day_scrapped': 1.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 22.0,
#   'Global_active_power': 1.5},
#  {'Global_reactive_power': 0.07,
#   'Voltage': 242.8,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 5.3,
#   'Day_scrapped': 9.0,
#   'Month_scrapped': 7.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 0.378},
#  {'Global_reactive_power': 0.168,
#   'Voltage': 240.52,
#   'Global_intensity': 3.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 14.233333333333333,
#   'Day_scrapped': 29.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 21.0,
#   'Global_active_power': 0.854},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 241.95,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.866666666666666,
#   'Day_scrapped': 11.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 5.0,
#   'Global_active_power': 0.352},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 241.33,
#   'Global_intensity': 5.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 4.233333333333334,
#   'Day_scrapped': 6.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 7.0,
#   'Global_active_power': 1.394},
#  {'Global_reactive_power': 0.38,
#   'Voltage': 233.15999999999997,
#   'Global_intensity': 13.9,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 1.0,
#   'Sub_metering_3': 16.0,
#   'power_consumption': 37.266666666666666,
#   'Day_scrapped': 2.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 3.256},
#  {'Global_reactive_power': 0.178,
#   'Voltage': 239.91,
#   'Global_intensity': 6.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 5.166666666666668,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 12.0,
#   'Global_active_power': 1.45},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 239.78,
#   'Global_intensity': 6.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 7.300000000000001,
#   'Day_scrapped': 10.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 1.578},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 243.79,
#   'Global_intensity': 1.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 5.733333333333333,
#   'Day_scrapped': 29.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.404},
#  {'Global_reactive_power': 0.132,
#   'Voltage': 242.99,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 5.833333333333333,
#   'Day_scrapped': 14.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 23.0,
#   'Global_active_power': 0.35},
#  {'Global_reactive_power': 0.174,
#   'Voltage': 244.91,
#   'Global_intensity': 7.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 19.0,
#   'power_consumption': 9.766666666666666,
#   'Day_scrapped': 26.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 20.0,
#   'Global_active_power': 1.726},
#  {'Global_reactive_power': 0.084,
#   'Voltage': 242.14,
#   'Global_intensity': 3.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 9.6,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 15.0,
#   'Global_active_power': 0.636},
#  {'Global_reactive_power': 0.102,
#   'Voltage': 240.95,
#   'Global_intensity': 2.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 9.566666666666666,
#   'Day_scrapped': 20.0,
#   'Month_scrapped': 3.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 0.634},
#  {'Global_reactive_power': 0.056,
#   'Voltage': 241.05,
#   'Global_intensity': 5.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 21.066666666666666,
#   'Day_scrapped': 13.0,
#   'Month_scrapped': 11.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 18.0,
#   'Global_active_power': 1.324},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 238.71,
#   'Global_intensity': 0.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 2.1,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 11.0,
#   'Global_active_power': 0.126},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 240.96,
#   'Global_intensity': 0.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 1.4666666666666668,
#   'Day_scrapped': 20.0,
#   'Month_scrapped': 9.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 8.0,
#   'Global_active_power': 0.148},
#  {'Global_reactive_power': 0.112,
#   'Voltage': 239.44,
#   'Global_intensity': 10.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 17.0,
#   'power_consumption': 24.766666666666666,
#   'Day_scrapped': 14.0,
#   'Month_scrapped': 2.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 19.0,
#   'Global_active_power': 2.506},
#  {'Global_reactive_power': 0.196,
#   'Voltage': 233.15999999999997,
#   'Global_intensity': 1.4,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.833333333333333,
#   'Day_scrapped': 8.0,
#   'Month_scrapped': 6.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 14.0,
#   'Global_active_power': 0.29},
#  {'Global_reactive_power': 0.148,
#   'Voltage': 240.34,
#   'Global_intensity': 7.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 18.0,
#   'power_consumption': 11.3,
#   'Day_scrapped': 21.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 10.0,
#   'Global_active_power': 1.758},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 241.73,
#   'Global_intensity': 4.8,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 19.4,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 12.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 17.0,
#   'Global_active_power': 1.164},
#  {'Global_reactive_power': 0.254,
#   'Voltage': 243.24,
#   'Global_intensity': 2.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 9.133333333333333,
#   'Day_scrapped': 27.0,
#   'Month_scrapped': 8.0,
#   'Year_scrapped': 2009.0,
#   'Hour_of_day': 20.0,
#   'Global_active_power': 0.608},
#  {'Global_reactive_power': 0.296,
#   'Voltage': 238.11,
#   'Global_intensity': 2.0,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 2.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 3.8,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2010.0,
#   'Hour_of_day': 2.0,
#   'Global_active_power': 0.408},
#  {'Global_reactive_power': 0.122,
#   'Voltage': 243.19,
#   'Global_intensity': 1.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 1.0,
#   'power_consumption': 5.0,
#   'Day_scrapped': 17.0,
#   'Month_scrapped': 4.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.36},
#  {'Global_reactive_power': 0.0,
#   'Voltage': 239.66,
#   'Global_intensity': 0.6,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 2.1666666666666665,
#   'Day_scrapped': 7.0,
#   'Month_scrapped': 10.0,
#   'Year_scrapped': 2007.0,
#   'Hour_of_day': 13.0,
#   'Global_active_power': 0.13},
#  {'Global_reactive_power': 0.064,
#   'Voltage': 240.74,
#   'Global_intensity': 1.2,
#   'Sub_metering_1': 0.0,
#   'Sub_metering_2': 0.0,
#   'Sub_metering_3': 0.0,
#   'power_consumption': 4.366666666666666,
#   'Day_scrapped': 11.0,
#   'Month_scrapped': 5.0,
#   'Year_scrapped': 2008.0,
#   'Hour_of_day': 3.0,
#   'Global_active_power': 0.262},
#  ...]

# %%
df_mongo.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001D1DE442040>

# %%
import pymongo


client = pymongo.MongoClient("mongodb+srv://Tandon78:Hellodude123@tandon.el8wcqy.mongodb.net/?retryWrites=true&w=majority")
db = client.test
db1 = client['RegressionModel']
coll = db1["Data"]

# %%
coll.insert_many(p)

# %%
pickle_prepro_df=pickle.load(open('preprocess_model.pkl','rb'))

# %%
pickle_prepro_df[2]
# Out:
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 15934                    0.000   238.36               7.0             0.0
# 2019140                  0.046   237.52              13.9             0.0
# 378247                   0.102   238.66               1.0             0.0
# 1071944                  0.108   248.35               1.4             0.0
# 1197909                  0.132   244.95               1.8             0.0
# ...                        ...      ...               ...             ...
# 1841193                  0.320   237.57               6.4             0.0
# 938603                   0.190   238.97               6.2             0.0
# 876667                   0.256   241.06               1.4             0.0
# 904932                   0.000   240.99               0.6             0.0
# 335865                   0.212   236.87               1.6             0.0
#
#          Sub_metering_2  Sub_metering_3  power_consumption  Day_scrapped  \
# 15934               0.0             0.0          28.433333            27
# 2019140             0.0            18.0          38.000000            18
# 378247              2.0             0.0           1.600000             9
# 1071944             0.0             0.0           5.366667            30
# 1197909             0.0             0.0           6.733333            27
# ...                 ...             ...                ...           ...
# 1841193             1.0            18.0           6.166667            17
# 938603              0.0            18.0           6.333333            28
# 876667              0.0             1.0           3.400000            16
# 904932              0.0             1.0           1.566667             9
# 335865              0.0             0.0           5.000000             8
#
#          Month_scrapped  Year_scrapped  Hour_of_day
# 15934                12           2006           18
# 2019140              10           2010           21
# 378247                5           2007            9
# 1071944              12           2008            3
# 1197909               3           2009           14
# ...                 ...            ...          ...
# 1841193               6           2010            7
# 938603                9           2008           12
# 876667                8           2008           12
# 904932                5           2008            3
# 335865                6           2007           23
#
# [16500 rows x 11 columns]

# %%
X_train=pickle_prepro_df[0]
y_train=pickle_prepro_df[1]
X_test=pickle_prepro_df[2]
y_test=pickle_prepro_df[3]

# %%
# Now Model Training

# %%
from sklearn.linear_model import LinearRegression

lin_reg=LinearRegression()

# %%
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lin_reg_pred=lin_reg.predict(X_test)

# %%
lin_reg_pred
# Out:
# array([1.706, 3.36 , 0.216, ..., 0.264, 0.154, 0.3  ])

# %%
plt.scatter(y_test,lin_reg_pred)
plt.xlabel("test_truth data")
plt.ylabel("test_predicted_data")
# Out:
# Text(0, 0.5, 'test_predicted_data')

# %%
# Residuals( Basically errors)
residuals=y_test-lin_reg_pred

# %%
residuals
# Out:
# 15934      2.220446e-16
# 2019140    0.000000e+00
# 378247    -5.551115e-17
# 1071944    7.216450e-16
# 1197909    0.000000e+00
#                ...
# 1841193   -6.661338e-16
# 938603    -2.220446e-16
# 876667    -4.996004e-16
# 904932     0.000000e+00
# 335865    -8.881784e-16
# Name: Global_active_power, Length: 16500, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
print(mean_squared_error(y_test,lin_reg_pred))

print(mean_absolute_error(y_test,lin_reg_pred))
# Out:
# 1.6582833432927147e-31
# 3.092004766703019e-16

# %%
np.sqrt(mean_squared_error(y_test,lin_reg_pred))
# Out:
# 4.0722025284761007e-16

# %%
# Now Performance Matrices

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,lin_reg_pred)

# %%
score
# Out:
# 1.0

# %%
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 1.0

# %%
# R2 and adjusted R2

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(y_test,lin_reg_pred)
r2
# Out:
# 1.0

# %%
adj_r2=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

# %%
adj_r2
# Out:
# 1.0

# %%
lin_reg_pred
# Out:
# array([1.706, 3.36 , 0.216, ..., 0.264, 0.154, 0.3  ])

# %%
y_test
# Out:
# 15934      1.706
# 2019140    3.360
# 378247     0.216
# 1071944    0.322
# 1197909    0.404
#            ...
# 1841193    1.510
# 938603     1.460
# 876667     0.264
# 904932     0.154
# 335865     0.300
# Name: Global_active_power, Length: 16500, dtype: float64

# %%
# Ridge

# %%
from sklearn.linear_model import Ridge
rid_reg=Ridge()

# %%
rid_reg.fit(X_train,y_train)
# Out:
# Ridge()

# %%
rid_reg_pred=rid_reg.predict(X_test)

# %%
rid_reg_pred
# Out:
# array([1.70599466, 3.36000098, 0.2159912 , ..., 0.26400713, 0.15399667,
#        0.30000775])

# %%
# Residuals( Basically errors)
residuals=y_test-rid_reg_pred

# %%
residuals
# Out:
# 15934      5.338115e-06
# 2019140   -9.793011e-07
# 378247     8.803383e-06
# 1071944   -4.079664e-06
# 1197909   -4.403002e-06
#                ...
# 1841193    4.024806e-06
# 938603    -4.595417e-06
# 876667    -7.130853e-06
# 904932     3.329904e-06
# 335865    -7.745874e-06
# Name: Global_active_power, Length: 16500, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


print(mean_squared_error(y_test,rid_reg_pred))

print(mean_absolute_error(y_test,rid_reg_pred))
# Out:
# 6.885068891289416e-11
# 5.35389590463698e-06

# %%
np.sqrt(mean_squared_error(y_test,rid_reg_pred))
# Out:
# 8.297631524290179e-06

# %%
# Now Performance Matrices

# %%
# R2 and adjusted R2

from sklearn.metrics import r2_score

r2=r2_score(y_test,rid_reg_pred)
r2
# Out:
# 0.999999999917728

# %%
adj_r2=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

adj_r2
# Out:
# 0.9999999999176732

# %%
# Lasso

# %%
from sklearn.linear_model import Lasso
las_reg=Lasso()

# %%
las_reg.fit(X_train,y_train)
# Out:
# Lasso()

# %%
las_reg_pred=las_reg.predict(X_test)

# %%
las_reg_pred
# Out:
# array([1.71231957, 3.09007413, 0.25112642, ..., 0.39674476, 0.29691169,
#        0.43627139])

# %%
# Residuals( Basically errors)
residuals=y_test-las_reg_pred

# %%
residuals
# Out:
# 15934     -0.006320
# 2019140    0.269926
# 378247    -0.035126
# 1071944   -0.134238
# 1197909   -0.126659
#              ...
# 1841193    0.153391
# 938603     0.094315
# 876667    -0.132745
# 904932    -0.142912
# 335865    -0.136271
# Name: Global_active_power, Length: 16500, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


print(mean_squared_error(y_test,las_reg_pred))

print(mean_absolute_error(y_test,las_reg_pred))
# Out:
# 0.020684825245812145
# 0.12447462636715555

# %%
np.sqrt(mean_squared_error(y_test,las_reg_pred))
# Out:
# 0.14382220011462815

# %%
# Now Performance Matrices

# %%
# R2 and adjusted R2

from sklearn.metrics import r2_score

r2=r2_score(y_test,las_reg_pred)
r2
# Out:
# 0.9752830277615998

# %%
adj_r2=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

adj_r2
# Out:
# 0.975266537787399

# %%
# ElasticNet

# %%
from sklearn.linear_model import ElasticNet
elas_reg=ElasticNet()

# %%
elas_reg.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
elas_reg_pred=elas_reg.predict(X_test)

# %%
elas_reg_pred
# Out:
# array([1.72679353, 3.23970438, 0.18642197, ..., 0.34329207, 0.23804929,
#        0.38159948])

# %%
# Residuals( Basically errors)
residuals=y_test-elas_reg_pred

# %%
residuals
# Out:
# 15934     -0.020794
# 2019140    0.120296
# 378247     0.029578
# 1071944   -0.080648
# 1197909   -0.077102
#              ...
# 1841193    0.097693
# 938603     0.038125
# 876667    -0.079292
# 904932    -0.084049
# 335865    -0.081599
# Name: Global_active_power, Length: 16500, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


print(mean_squared_error(y_test,elas_reg_pred))

print(mean_absolute_error(y_test,elas_reg_pred))
# Out:
# 0.007147362982537142
# 0.07079405934944492

# %%
np.sqrt(mean_squared_error(y_test,elas_reg_pred))
# Out:
# 0.08454207817730258

# %%
# Now Performance Matrices

# %%
# R2 and adjusted R2

from sklearn.metrics import r2_score

r2=r2_score(y_test,elas_reg_pred)
r2
# Out:
# 0.9914593828897391

# %%
adj_r2=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

adj_r2
# Out:
# 0.9914536850010799

# %%
from sklearn.svm import SVR
svr=SVR()

# %%
svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
svr_pred=svr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(y_test,svr_pred)
r2
# Out:
# 0.9895187655969674

# %%
adj_r2=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

adj_r2
# Out:
# 0.9895117730218562

# %%
# Hyperparameter Tuning

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import GridSearchCV

# %%
#defining the parameter range
param_grid={'C': [0.1,10],
           'gamma': [1,0.1],
           'kernel': ['rbf']}

grid=GridSearchCV(SVR(),param_grid, refit=True, verbose= 3)

# %%
#fitting the model for grid search
grid_search=grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.165 total time= 1.4min
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.171 total time= 1.5min
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.147 total time= 1.1min
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.159 total time= 1.1min
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.157 total time= 1.1min
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.744 total time= 1.0min
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.735 total time= 1.1min
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.738 total time= 1.1min
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.734 total time= 1.0min
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.730 total time= 1.2min
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.189 total time= 5.1min
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.180 total time= 5.1min
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.178 total time= 7.1min
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.174 total time= 6.7min
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.165 total time= 5.7min
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.947 total time= 2.0min
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.941 total time= 1.8min
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.944 total time= 1.9min
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.943 total time= 2.1min
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.938 total time= 2.2min

# %%
grid_search.best_params_
# Out:
# {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
grid_search.best_score_
# Out:
# 0.9423312804183637

# %%
# ThankYou!
